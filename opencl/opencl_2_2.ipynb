# %%
kernel = """
    #define TRACE_LENGTH 100
    
    __constant uchar sbox[] = {
      
};

uint my_popcount(uint x) {
    uint count;
    for (count = 0; x; count++) {
        x &= x - 1;
    }
    return count;
}

float mean(float* X, int len) {
    float sum = 0;
    for (int i = 0; i < len; i++) {
        sum += X[i];
    }
    return sum / len;
}

float std_dev(float* X, float X_bar, int len) {
    float sum = 0;
    for (int i = 0; i < len; i++) {
        sum += (X[i] - X_bar) * (X[i] - X_bar);
    }
    return sqrt(sum); 
}


__kernel void attack(__global uchar* textin_array, __global double* trace_array, int trace_array_len, __global uchar* bestguess, __global float* cparefs)  {
    int bnum = get_global_id(0);
    int num_text_inputs = trace_array_len;
    double t_bar = 0.0, o_t = 0.0;
    double maxcpa = 0;
    uchar key_byte_guess = 0;
    float hws[50];
    double max_correlation = -1.0; 
    double correlation_array[TRACE_LENGTH];
    double o_t_array[TRACE_LENGTH];
    double t_bar_array[TRACE_LENGTH];
    
    // calc t_bar
    for (int j = 0; j < TRACE_LENGTH; j++) {
        double sum = 0;
        for (int i = 0; i < num_text_inputs; i++) {
            sum += trace_array[i * TRACE_LENGTH + j];
        }
        t_bar_array[j] = sum / num_text_inputs;
    }

    // calc o_t
    for (int j = 0; j < TRACE_LENGTH; j++) {
        double sum = 0;
        for (int i = 0; i < num_text_inputs; i++) {
            double diff = trace_array[i * TRACE_LENGTH + j] - t_bar_array[j];
            sum += diff * diff;
        }
        o_t_array[j] = sqrt(sum);
    }
    
    for (int kguess = 0; kguess < 256; kguess++) { 
        for (int i = 0; i < num_text_inputs; i++) {
                hws[i] = my_popcount(sbox[textin_array[i * 16 + bnum] ^ kguess]);
            }
            
        float hws_bar = mean(hws, num_text_inputs);
        float o_hws = std_dev(hws, hws_bar, num_text_inputs);
        
        for (int j = 0; j < TRACE_LENGTH; j++) {
            double sum = 0;
            for (int i = 0; i < num_text_inputs; i++) {
                double trace_diff = trace_array[i * TRACE_LENGTH + j] - t_bar_array[j];
                double hws_diff = hws[i] - hws_bar;
                sum += trace_diff * hws_diff;
            }
            correlation_array[j] = sum / (o_t_array[j] * o_hws);
            double correlation = fabs(correlation_array[j]);
            if (correlation > max_correlation) {
                max_correlation = correlation;
                key_byte_guess = kguess;
            }
        }
    }
    // Save the best guess and its correlation value in the output buffers
    bestguess[bnum] = key_byte_guess;
    cparefs[bnum] = max_correlation;
}
"""

# %%
import pyopencl as cl
from tqdm import tnrange
import numpy as np
import time

# Get the start time
st = time.time()

trace_array = np.load(r"trace_array.npy").astype(np.float64)
textin_array = np.load(r"textin_array.npy")
trace_array = trace_array[0:50]
textin_array = textin_array[0:50]

# Define the size of each chunk
chunk_size = 100  # Update this to the desired size
assert trace_array.shape[1] % chunk_size == 0, "The number of columns in trace_array must be divisible by the chunk size."

# Split the trace_array into chunks
trace_array_chunks = np.split(trace_array, trace_array.shape[1]//chunk_size, axis=1)
#rint(trace_array.shape[1])
#print(trace_array_chunks)
platforms = cl.get_platforms()
devices = platforms[0].get_devices()
ctx = cl.Context([devices[0]])
queue = cl.CommandQueue(ctx)
mf = cl.mem_flags

textin_array_buf = cl.Buffer(ctx, mf.READ_ONLY | mf.COPY_HOST_PTR, hostbuf=textin_array)
bestguess_buf = cl.Buffer(ctx, mf.WRITE_ONLY, size=16 * np.dtype(np.uint8).itemsize)
cparefs_buf = cl.Buffer(ctx, mf.WRITE_ONLY, size=16 * np.dtype(np.float32).itemsize)

numsubkeys = 16 

TRACE_LENGTH = chunk_size  # Oder welcher Wert auch immer benötigt wird

# Build the program
prg = cl.Program(ctx, kernel).build(options=['-D', f'TRACE_LENGTH={TRACE_LENGTH}'])

# Initialize the arrays to hold the best guesses and correlations for all chunks
bestguess_all = np.empty((len(trace_array_chunks), numsubkeys), dtype=np.uint8)
cparefs_all = np.empty((len(trace_array_chunks), numsubkeys), dtype=np.float32)
bestguess_chunks = []  # Initialize the array to hold the best guesses for each chunk
cparefs_chunks = []  # Initialize the array to hold the correlations for each chunk

for chunk_index, trace_array_part in enumerate(trace_array_chunks):
    # Adjust the numtraces variable to reflect the number of traces in this part of the array
    numtraces_part = trace_array_part.shape[0]
    #print(trace_array_part.shape[0])
    # Create a contiguous copy of trace_array_part before passing it to the buffer creation function
    trace_array_part_contig = np.ascontiguousarray(trace_array_part)
    
    trace_array_buf = cl.Buffer(ctx, mf.READ_ONLY | mf.COPY_HOST_PTR, hostbuf=trace_array_part_contig)
    # Perform the computations on this chunk of the array
    prg.attack(queue, (numsubkeys,), None, textin_array_buf, trace_array_buf, np.int32(numtraces_part), bestguess_buf, cparefs_buf)
    
    # Retrieve the best guesses and correlations for this chunk
    bestguess = np.empty(numsubkeys, dtype=np.uint8)
    cparefs = np.empty(numsubkeys, dtype=np.float32)
    cl.enqueue_copy(queue, bestguess, bestguess_buf)
    cl.enqueue_copy(queue, cparefs, cparefs_buf)
    
    # Store the best guesses and correlations for this chunk
    bestguess_all[chunk_index] = bestguess
    cparefs_all[chunk_index] = cparefs
    #print(bestguess)
    #print(cparefs)

# Determine the best result for each subkey across all chunks
best_indices = np.argmax(cparefs_all, axis=0)
best_cparefs = np.array([cparefs_all[best_indices[i], i] for i in range(numsubkeys)])
best_bestguess = np.array([bestguess_all[best_indices[i], i] for i in range(numsubkeys)])

# Get the end time
et = time.time()

# get the execution time
elapsed_time = et - st
print('Execution time:', elapsed_time, 'seconds')

for i, bestguess in enumerate(bestguess_chunks):
    print(f"Chunk {i+1} best guesses: {bestguess}")
# Out:
# Execution time: 3.8283307552337646 seconds
# Chunk 1 best guesses: [245 113 143 125  36 249 233 141 227 193 186 195  99  67 232  13]
# Chunk 2 best guesses: [203 154 208 143  60  70 241 218  43  71 189 110 242 227 213 168]
# Chunk 3 best guesses: [113 149 218  19 103  74 248  84 114 172 203   6  60   9  96 172]
# Chunk 4 best guesses: [ 80 212 218  13 146 115  70  84  49   8  18 237  69 161  54 145]
# Chunk 5 best guesses: [189 188 106  77 167  38  59 191  33  28 194 151 138  98  54  58]
# Chunk 6 best guesses: [205 188  35 135  24 104  71  97  98 148 186 163  94  46  23  58]
# Chunk 7 best guesses: [ 43 249 101 181  60 128  71  24 127 123  54 211 106  67  54  26]
# Chunk 8 best guesses: [106 145 196  77  97  44 111  60 165  91 183   1  42  98  54  71]
# Chunk 9 best guesses: [151 154 248 184  27 167  69 214  65  13  64  40 127 207   0 175]
# Chunk 10 best guesses: [142 154  44 200  16  59 176  75 193   7  23 172 131 169  54  27]
# Chunk 11 best guesses: [ 18  37 156 135 235 152 216  36 102 241 126 211 102 169  54   1]
# Chunk 12 best guesses: [ 27   7 235 199 188  39 216 117  24  28  21 189  86 177  98 146]
# Chunk 13 best guesses: [203 129 196 208  73  39 198 109 244  23  55 140 161 142 235 206]
# Chunk 14 best guesses: [ 43 183  62 184  40  53 238  20  79 123 186  80 161  67 105 112]
# Chunk 15 best guesses: [ 38 126 235  77 115  80 238 194 171  90 121 153   9 125  54 118]
